# %% [markdown]
# <a href="https://colab.research.google.com/github/evirevialle/notebook_python_folium/blob/main/dataset_nobles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href='https://www.dhi-paris.fr/fr/page-daccueil.html'><img src='https://th.bing.com/th/id/R.61028ff085975475c6beb093bfe05fae?rik=uz4xIq%2bK2BNFqA&riu=http%3a%2f%2ff-origin.hypotheses.org%2fwp-content%2fblogs.dir%2f411%2ffiles%2f2012%2f10%2fLOGO-DHIP_IHA.jpg&ehk=CCDsoocwGaxx5Ruh7ozf%2f%2bIk%2fuks24MZIgFIdBhbgwQ%3d&risl=&pid=ImgRaw&r=0' width='150' title='logo IHA'></a>
# ---------------------------------------
# ##Notebook Adressbuch
# This Notebook shows a part of Adressbuch's dataset.
# This dataset represents german nobles in Adressbuch who lived in Paris on XIX century.
# Notebook was encoded with Python
# * more informations to folium [click here](https://python-visualization.github.io/folium/index.html)
# * more informations to pandas [click here](https://pandas.pydata.org/)
#
# ### Project Adressbuch 1854 [click here](https://github.com/dhi-digital-humanities/Adressbuch)

# %%
def libraries():
  """
  This cell adds differents libraries from Python
  """
import pandas as pd
import folium
from folium import plugins
from folium.plugins import MiniMap, MarkerCluster
from folium.features import GeoJson, GeoJsonTooltip
import geopandas
import branca

# %%
help(libraries)
# Out:
# Help on function libraries in module __main__:
#
# libraries()
#     This cell adds differents libraries from Python

# %%
def dataset():
  """
  This cell loads dataset with pandas
  """
file = 'dataset-german-nobles-in-paris-1854.csv'
data = pd.read_csv(file, sep = ',' )
columns_number=data.shape[1]
noble_number=data.shape[0]
data
# Out:
#        id          surname first_name gender           title  \
# 0     587       Mackau von    Unknown      M           Baron
# 1     717          Schramm    Unknown      M            Graf
# 2    4110        Kronowski    Unknown      M            Graf
# 3      12           Badens    Unknown      F      Gräfin von
# 4      97        Hamel von    Unknown      M            Graf
# ..    ...              ...        ...    ...             ...
# 108  4078    Heeckeren von    Unknown      M           Baron
# 109  4108        Kronowska    Unknown      F  Gräfin v Tabaß
# 110  4767  Narischkine von    Unknown      F          Gräfin
# 111  1275   Ribbentrop von     Adolph      M           Baron
# 112  3750            Walsh    Unknown      F          Gräfin
#
#            profession_verbatim occupation_group legion_d_honneur     status  \
# 0             Admiral, Senator          Militär      Grand-Croix     Active
# 1    Divisionsgeneral, Senator          Militär      Grand-Croix     Active
# 2             Oberstlieutenant          Militär          Unknown     Active
# 3                      Unknown             Adel          Unknown     Active
# 4                      Unknown             Adel          Unknown     Active
# ..                         ...              ...              ...        ...
# 108                    Senator             Adel        Chevalier     Active
# 109                    Unknown             Adel          Unknown     Active
# 110                    Unknown             Adel          Unknown     Active
# 111                    Rentner          Rentner          Unknown  Pensioner
# 112              Eigenthümerin          Rentner          Unknown  Annuitant
#
#     military_status houseno houseno_specification name_old_verbatim  \
# 0          Military       7               Unknown      De Caumartin
# 1          Military      77               Unknown    Louis Le Grand
# 2          Military      44               Unknown  Basse Du Rempart
# 3             Civil       3               Unknown             Ferme
# 4             Civil      89               Unknown       De Grenelle
# ..              ...     ...                   ...               ...
# 108           Civil      84               Unknown    De La Victoire
# 109           Civil      44               Unknown  Basse Du Rempart
# 110           Civil      28                   bis         De Rivoli
# 111           Civil      23               Unknown       Neuve Bréda
# 112           Civil      82               Unknown  De L' Université
#
#                  name_new  geo_long  geo_lat
# 0        Rue De Caumartin   2.32824  48.8725
# 1      Rue Louis-le-grand   2.33258  48.8688
# 2                 Unknown   0.00000   0.0000
# 3                 Unknown   0.00000   0.0000
# 4          Rue De Lourmel   2.28751  48.8451
# ..                    ...       ...      ...
# 108    Rue De La Victoire   2.33521  48.8752
# 109               Unknown   0.00000   0.0000
# 110         Rue De Rivoli   2.35367  48.8569
# 111           Rue Clauzel   2.33829  48.8792
# 112  Rue De L' Université   2.31594  48.8609
#
# [113 rows x 16 columns]

# %%
help(dataset)
# Out:
# Help on function dataset in module __main__:
#
# dataset()
#     This cell loads dataset with pandas

# %%
def basemap():
  """
  This cell creates base map with Folium. Folium makes to visualize an interractive map with LeafletMap
  """
map = folium.Map(
    location=[48.8566969, 2.3514616], 
    zoom_start= 12, 
    control_scale=True, 
    max_bounds=True,
    max_lat=48.813141, max_lon=2.234129, 
    min_lat=48.908715, min_lon=2.422941,
    
    )     
map.fit_bounds([[48.813141,2.234129],[48.908715,2.422941]])

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_fe09d62774e943fdb2dfcd0156d8f423%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fe09d62774e943fdb2dfcd0156d8f423%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fe09d62774e943fdb2dfcd0156d8f423%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_fe09d62774e943fdb2dfcd0156d8f423%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B48.8566969%2C%202.3514616%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
help(basemap)
# Out:
# Help on function basemap in module __main__:
#
# basemap()
#     This cell creates base map with Folium. Folium makes to visualize an interractive map with LeafletMap

# %%
def raster_layer():
  """
  This cell creates an old map with folium.raste_layers. This Map is an old map. 
  We can download the map on Geoportail.gouv. 
  Old map was made on nineteenth century
  """
folium.raster_layers.TileLayer(
    tiles="https://wxs.ign.fr/cartes/geoportail/wmts?" + "&REQUEST=GetTile&SERVICE=WMTS&VERSION=1.0.0" +
        "&STYLE=normal" +
        "&TILEMATRIXSET=PM" +
        "&FORMAT=image/jpeg"+
        "&LAYER=GEOGRAPHICALGRIDSYSTEMS.ETATMAJOR40"+
    "&TILEMATRIX={z}" +
        "&TILEROW={y}" +
        "&TILECOL={x}", 
        name="Carte d'Etat Major 1822-1866",
        attr='IGN-F/Geoportail'
        ).add_to(map)

folium.LayerControl().add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_fe09d62774e943fdb2dfcd0156d8f423%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fe09d62774e943fdb2dfcd0156d8f423%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fe09d62774e943fdb2dfcd0156d8f423%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_fe09d62774e943fdb2dfcd0156d8f423%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B48.8566969%2C%202.3514616%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
help(raster_layer)
# Out:
# Help on function raster_layer in module __main__:
#
# raster_layer()
#     This cell creates an old map with folium.raste_layers. This Map is an old map.
#     We can download the map on Geoportail.gouv.
#     Old map was made on nineteenth century

# %%
def add_markers():
  """
  . Create 'boucle' with Python to see markers on base map and old map
  . take 'lattitude'(geo_lat) and 'longitude'(geo_long) in dataset to create variable 'location'
  . take other informations (surname, first_name, gender) to create variable 'legende'
  . encode folium.Marker with variable 'location' and 'legende'
  . add on base map
  """

for i in range(data.shape[0]):
    location=[data['geo_lat'][i],data['geo_long'][i]]
    legende="<strong>Title</strong> : " 
    legende+= data['title'][i] 
    legende+= "<br><strong>Surname</strong> : " 
    legende+= data['surname'][i]
    legende+= "<br><strong>First name</strong> : "
    legende+= data['first_name'][i]
    legende+= "<br><strong>Profession</strong> : "
    legende+= data['profession_verbatim'][i]
  
    tooltip= folium.Tooltip(text=legende, style='color: green;')
    folium.Marker(location, popup=(legende), tooltip=tooltip).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_fe09d62774e943fdb2dfcd0156d8f423%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fe09d62774e943fdb2dfcd0156d8f423%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fe09d62774e943fdb2dfcd0156d8f423%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_fe09d62774e943fdb2dfcd0156d8f423%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B48.8566969%2C%202.3514616%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
help(add_markers)
# Out:
# Help on function add_markers in module __main__:
#
# add_markers()
#     . Create 'boucle' with Python to see markers on base map and old map
#     . take 'lattitude'(geo_lat) and 'longitude'(geo_long) in dataset to create variable 'location'
#     . take other informations (surname, first_name, gender) to create variable 'legende'
#     . encode folium.Marker with variable 'location' and 'legende'
#     . add on base map

# %%
def dual_map():
  """
  The DualMap plugin can be used to display two maps side by side, where panning and zooming is syncronized.
  """
m = plugins.DualMap(location=[48.8566969, 2.3514616], 
                    layout='horizontal',
                    tiles=None,
                    zoom_start= 12, 
                    control_scale=True, 
                    max_bounds=True,
                    max_lat=48.813141, max_lon=2.234129, 
                    min_lat=48.908715, min_lon=2.422941,
                    )

folium.TileLayer("https://wxs.ign.fr/cartes/geoportail/wmts?" + "&REQUEST=GetTile&SERVICE=WMTS&VERSION=1.0.0" +
        "&STYLE=normal" +
        "&TILEMATRIXSET=PM" +
        "&FORMAT=image/jpeg"+
        "&LAYER=GEOGRAPHICALGRIDSYSTEMS.ETATMAJOR40"+
    "&TILEMATRIX={z}" +
        "&TILEROW={y}" +
        "&TILECOL={x}",
        name="Carte d'Etat Major 1822-1866",
        attr='IGN-F/Geoportail'
        ).add_to(m.m2)

folium.TileLayer("openstreetmap").add_to(m.m1)

folium.LayerControl(collapsed=False).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_44157525fce243abbff62d071d49e4bb%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20absolute%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%2050.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c79720b9e7a44a7e90233bf92d655cb4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20absolute%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%2050.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20 ...

# %%
help(dual_map)
# Out:
# Help on function dual_map in module __main__:
#
# dual_map()
#     The DualMap plugin can be used to display two maps side by side, where panning and zooming is syncronized.

# %%
help(add_markers)
# Out:
# Help on function add_markers in module __main__:
#
# add_markers()
#     . Create 'boucle' with Python to see markers on base map and old map
#     . take 'lattitude'(geo_lat) and 'longitude'(geo_long) in dataset to create variable 'location'
#     . take other informations (surname, first_name, gender) to create variable 'legende'
#     . encode folium.Marker with variable 'location' and 'legende'
#     . add on base map

# %%
for i in range(data.shape[0]):
    location=[data['geo_lat'][i],data['geo_long'][i]]
    legende="<strong>Title</strong> : " 
    legende+= data['title'][i] 
    legende+= "<br><strong>Surname</strong> : " 
    legende+= data['surname'][i]
    legende+= "<br><strong>First name</strong> : "
    legende+= data['first_name'][i]
    legende+= "<br><strong>Profession</strong> : "
    legende+= data['profession_verbatim'][i]
    legende+= "<br><strong>Gender</strong> : "
    legende+= data['gender'][i]


    folium.Marker(location, popup=(legende), tooltip=(legende)).add_to(m)
 
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_44157525fce243abbff62d071d49e4bb%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20absolute%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%2050.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c79720b9e7a44a7e90233bf92d655cb4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20absolute%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%2050.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20 ...

# %%
def data_geojson():
  """
  With geojson data from ALPAGE project, we can see differents which were historic districts of Paris on nineteenth century
  """
Quartiers = f'Export_Quartiers__Vasserot_.zip'
shp_file = geopandas.read_file(Quartiers)


shp_file
# Out:
#     id  geo_fid     geo_creati     geo_modifi ID_ALPAGE  \
# 0    1        1  1530006986543  1530006986543      QU46
# 1    2        2  1530006986544  1530006986544      QU32
# 2    3        3  1530006986545  1530006986545      QU47
# 3    6        6  1530006986548  1530006986548      QU42
# 4    7        7  1530006986548  1530006986548      QU33
# 5    4        4  1530006986546  1530006986546      QU38
# 6    5        5  1530006986547  1530006986547      QU39
# 7   16       16  1530006986557  1530006986557      QU28
# 8    8        8  1530006986550  1530006986550      QU31
# 9    9        9  1530006986550  1530006986550      QU36
# 10  13       13  1530006986555  1530006986555      QU29
# 11  10       10  1530006986551  1530006986551      QU37
# 12  11       11  1530006986553  1530006986553      QU35
# 13  14       14  1530006986556  1530006986556      QU27
# 14  12       12  1530006986554  1530006986554      QU34
# 15  15       15  1530006986557  1530006986557      QU44
# 16  17       17  1530006986558  1530006986558      QU14
# 17  18       18  1530006986560  1530006986560      QU23
# 18  33       33  1530006986578  1530006986578      QU19
# 19  19       19  1530006986561  1530006986561      QU26
# 20  20       20  1530006986562  1530006986562      QU25
# 21  21       21  1530006986563  1530006986563      QU15
# 22  22       22  1530006986565  1530006986565      QU13
# 23  23       23  1530006986566  1530006986566       QU2
# 24  24       24  1530006986567  1530006986567       QU4
# 25  25       25  1530006986569  1530006986569      QU11
# 26  26       26  1530006986570  1530006986570      QU16
# 27  27       27  1530006986571  1530006986571      QU24
# 28  28       28  1530006986572  1530006986572      QU20
# 29  29       29  1530006986574  1530006986574       QU6
# 30  30       30  1530006986575  1530006986575      QU22
# 31  31       31  1530006986576  1530006986576      QU21
# 32  32       32  1530006986577  1530006986577      QU12
# 33  34       34  1530006986579  1530006986579       QU7
# 34  35       35  1530006986580  1530006986580      QU10
# 35  36       36  1530006986581  1530006986581      QU17
# 36  38       38  1530006986585  1530006986585       QU9
# 37  37       37  1530006986583  1530006986583       QU1
# 38  39       39  1530006986586  1530006986586       QU8
# 39  40       40  1530006986587  1530006986587       QU5
# 40  41       41  1530006986589  1530006986589      QU18
# 41  42       42  1530006986590  1530006986590      QU30
# 42  43       43  1530006986592  1530006986592      QU43
# 43  45       45  1530006986597  1530006986597      QU48
# 44  44       44  1530006986595  1530006986595      QU45
# 45  46       46  1530006986599  1530006986599      QU41
# 46  47       47  1530006986600  1530006986600      QU40
# 47  48       48  1530006986601  1530006986601       QU3
#
#                         NOM  NUM_ARROND  NUM_QUARTI  \
# 0              Saint-Marcel          12          46
# 1             Quinze-Vingts           8          32
# 2             Jardin du Roi          12          47
# 3         Ecole de Medecine          11          42
# 4           Ile Saint-Louis           9          33
# 5      Saint-Thomas d'Aquin          10          38
# 6                 Invalides          10          39
# 7                     Arcis           7          28
# 8    Faubourg Saint-Antoine           8          31
# 9                   Arsenal           9          36
# 10                   Marais           8          29
# 11                  Monnaie          10          37
# 12                     Cite           9          35
# 13        Marche Saint-Jean           7          27
# 14           Hotel de Ville           9          34
# 15        Palais de Justice          11          44
# 16                   Louvre           4          14
# 17                 Lombards           6          23
# 18           Bonne Nouvelle           5          19
# 19            Mont de Piete           7          26
# 20             Sainte-Avoie           7          25
# 21                  Marches           4          15
# 22             Saint-Honore           4          13
# 23           Champs-Elysees           1           2
# 24                Tuileries           1           4
# 25           Saint-Eustache           3          11
# 26         Banque de France           4          16
# 27                   Temple           6          24
# 28              Montorgueil           5          20
# 29             Palais-Royal           2           6
# 30  Saint-Martin-des-Champs           6          22
# 31        Porte Saint-Denis           6          21
# 32                     Mail           3          12
# 33                  Feydeau           2           7
# 34               Montmartre           3          10
# 35     Faubourg Saint-Denis           5          17
# 36    Faubourg Poissonniere           3           9
# 37                    Roule           1           1
# 38      Faubourg Montmartre           2           8
# 39         Chaussee d'Antin           2           5
# 40       Porte Saint-Martin           5          18
# 41               Popincourt           8          30
# 42                 Sorbonne          11          43
# 43             Observatoire          12          48
# 44            Saint-Jacques          12          45
# 45               Luxembourg          11          41
# 46   Faubourg Saint-Germain          10          40
# 47            Place Vendome           1           3
#
#                                              BHVP_NUM  BHVP_MANU  ATLAS_BELL  \
# 0                                      non represente        0.0           0
# 1                                      non represente        0.0           1
# 2                                      non represente        0.0           0
# 3                                      non represente        0.0           1
# 4                                  27, Revise en 1850        1.0           1
# 5                                      non represente        0.0           1
# 6                                      non represente        0.0           1
# 7                                      non represente        0.0           1
# 8                                      non represente        0.0           1
# 9                                      non represente        0.0           1
# 10                                     non represente        0.0           1
# 11                                     non represente        0.0           1
# 12                                 29, revise en 1850        1.0           1
# 13                                     non represente        0.0           1
# 14                                                 28        1.0           1
# 15                                     non represente        0.0           1
# 16                                                 14        1.0           1
# 17                                                 24        1.0           1
# 18                                     non represente        0.0           1
# 19                                     non represente        0.0           1
# 20                                     non represente        0.0           1
# 21                                                 15        1.0           1
# 22                                     non represente        0.0           1
# 23                                             2 et 4        1.0           0
# 24               6 mais partie orientale pas dessinee        0.5           1
# 25                                     13, avril 1848        1.0           1
# 26                                                 16        1.0           1
# 27                                                 25        1.0           0
# 28                                     non represente        0.0           1
# 29                                                  8        1.0           1
# 30                                                 23        1.0           0
# 34  POLYGON ((651921.326 6863668.234, 651929.306 6...
# 35  POLYGON ((652733.713 6863429.210, 652730.538 6...
# 36  POLYGON ((652778.772 6864328.528, 652776.084 6...
# 37  POLYGON ((650686.746 6865005.096, 650696.041 6...
# 38  POLYGON ((652247.935 6864324.188, 652245.863 6...
# 39  POLYGON ((651157.106 6863641.549, 651155.379 6...
# 40  POLYGON ((654291.091 6863736.808, 654280.546 6...
# 41  POLYGON ((655412.413 6861936.285, 655401.578 6...
# 42  POLYGON ((652029.518 6861667.152, 652072.974 6...
# 43  POLYGON ((651706.842 6860835.483, 651729.760 6...
# 44  POLYGON ((652450.660 6861399.520, 652444.486 6...
# 45  POLYGON ((651589.804 6861056.960, 651579.840 6...
# 46  POLYGON ((650496.356 6862526.204, 650614.062 6...
# 47  POLYGON ((651069.881 6863960.280, 651076.683 6...

# %%
help(data_geojson)
# Out:
# Help on function data_geojson in module __main__:
#
# data_geojson()
#     With geojson data from ALPAGE project, we can see differents which were historic districts of Paris on nineteenth century

# %%
def Geojson():
  """
  We use data from ALPAGE's project to show the old districts and old arrondissements in Paris on nineteenth century. 
  This script require additional folium features (GeoJson, GeoJsonTooltip)
  """
map3 = folium.Map(
    location=[48.8566969, 2.3514616], 
    zoom_start= 12, 
    control_scale=True, 
    max_bounds=True,
    max_lat=48.813141, max_lon=2.234129, 
    min_lat=48.908715, min_lon=2.422941,
    
    )  
quartiers = folium.GeoJsonTooltip(
    fields=['NOM','NUM_ARROND','DATE_COYEC'],
    aliases=['Quartiers :','Arrondissement :','Date :'],
)
folium.GeoJson(
    shp_file, 
    style_function=lambda x:{'color':'black'},
    tooltip= quartiers,
    name='Quartiers de Paris').add_to(map3)
 

folium.raster_layers.TileLayer(
    tiles="https://wxs.ign.fr/cartes/geoportail/wmts?" + "&REQUEST=GetTile&SERVICE=WMTS&VERSION=1.0.0" +
        "&STYLE=normal" +
        "&TILEMATRIXSET=PM" +
        "&FORMAT=image/jpeg"+
        "&LAYER=GEOGRAPHICALGRIDSYSTEMS.ETATMAJOR40"+
    "&TILEMATRIX={z}" +
        "&TILEROW={y}" +
        "&TILECOL={x}", 
        name="Carte d'Etat Major 1822-1866",
        attr='IGN-F/Geoportail'
        ).add_to(map3)

folium.LayerControl().add_to(map3)

"""
I take dataset to add markers on map3
"""

for i in range(data.shape[0]):
  location=[data['geo_lat'][i],data['geo_long'][i]]
  legende="<strong>Title</strong> : " 
  legende+= data['title'][i] 
  legende+= "<br><strong>Surname</strong> : " 
  legende+= data['surname'][i]
  legende+= "<br><strong>First name</strong> : "
  legende+= data['first_name'][i]
  legende+= "<br><strong>Profession</strong> : "
  legende+= data['profession_verbatim'][i]
  legende+= "<br><strong>Gender</strong> : "
  legende+= data['gender'][i]

  folium.Marker(location, popup=(legende), tooltip=(legende)).add_to(map3)

map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_6d9d23185e44404c81580854e7e84069%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20table%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20margin%3A%20auto%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
help(Geojson)
